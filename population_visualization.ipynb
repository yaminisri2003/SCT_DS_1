# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("population_data.csv", skiprows=4)
df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130075728.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
# 3   97630925.0   99706674.0  101854756.0  104089175.0  106388440.0
# 4    5231654.0    5301583.0    5354310.0    5408320.0    5464187.0
#
#           1965  ...         2016         2017         2018         2019  \
# ...

# %%
india_data = df[df["Country Name"] == "India"]
india_data
# Out:
#     Country Name Country Code     Indicator Name Indicator Code         1960  \
# 109        India          IND  Population, total    SP.POP.TOTL  435990338.0
#
#             1961         1962         1963         1964         1965  ...  \
# 109  446564729.0  457283090.0  468138575.0  479229598.0  490140146.0  ...
#
#              2016          2017          2018          2019          2020  \
# 109  1.343944e+09  1.359657e+09  1.374659e+09  1.389030e+09  1.402618e+09
#
#              2021          2022          2023          2024  Unnamed: 69
# 109  1.414204e+09  1.425423e+09  1.438070e+09  1.450936e+09          NaN
#
# [1 rows x 70 columns]

# %%
years = india_data.columns[4:-1]
pop = india_data.loc[:, years].values.flatten()
years = [int(y) for y in years]
pop = [int(p)/1e9 for p in pop]

plt.figure(figsize=(10,5))
plt.plot(years, pop, marker='o', color='green')
plt.title("India's Population Over Time")
plt.xlabel("Year")
plt.ylabel("Population (Billions)")
plt.grid(True)
plt.show()

# %%
age_groups = ['0–20 years', '21–64 years', '65+ years']
populations = [512, 807, 98]  # In millions

plt.bar(age_groups, populations, color=['gold', 'blue', 'pink'])
plt.title("India's Population Distribution by Age (2022)")
plt.xlabel("Age Group")
plt.ylabel("Population (Millions)")
plt.grid(axis='y')
plt.show()
